# %%
# Databricks notebook source

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/prod_prct/prod_asset_sch/prod_asset_vlm/landing_files.csv")

df.display()

# DBTITLE 1,Write to Delta (Bronze layer)

df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("prod_prct.prod_asset_sch.landing_asset_check1")

print("Ingestion complete: bronze_population_data")
